# %%
import sys
import os
import 
current_dir = os.getcwd()
sys.path.append(current_dir+'/pkg/')
import utils
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/kh/vl9gbzb95hsg7d0rn6lhqtvm0000gp/T/ipykernel_71599/660709424.py in <module>
#       3 current_dir = os.getcwd()
#       4 sys.path.append(current_dir+'../pkg/')
# ----> 5 import utils
#
# ModuleNotFoundError: No module named 'utils'

# %%
name = 'Martin Barry'
profiles = utils.getScholarID(name)
# Out:
# name Martin+Barry  User ID: WGPtE0oAAAAJ
# extracting author results..
# Parsing Barry Martin
# {'name': 'Kevin Oxborough', 'id': '6vvqTZcAAAAJ'}
# extracting author results..
# Parsing Kevin Oxborough
# name Martin+Barry  User ID: eMTj19QAAAAJ
# extracting author results..
# Parsing Martin Barry
# {'name': 'Wulfram Gerstner', 'id': 'vSd2RnEAAAAJ'}
# {'name': 'Guillaume BELLEC', 'id': 'fSXUVvAAAAAJ'}
# already scraped
# Wulfram Gerstner
# already scraped
# Guillaume BELLEC
# already scraped
# Wolfgang Maass
# already scraped
# Robert Legenstein
# already scraped
# Henry Markram
# already scraped
# Thomas Natschläger
# already scraped
# Franz Scherr
# already scraped
# Guillaume BELLEC
# already scraped
# Bernhard Nessler
# already scraped
# Eduardo Sontag
# already scraped
# Lars Buesing
# already scraped
# Michael Pfeiffer
# already scraped
# Peter Auer
# already scraped
# Christos H PAPADIMITRIOU
# already scraped
# Christopher M. Bishop
# already scraped
# Dorit S. HOCHBAUM
# ...
